# %% [markdown]
# # Detection of trashy in video

# %% [markdown]
# ## Test 1

# %%
# !python yolov5/detect.py \
    --weights /home/mathias/Documents/project_in_ai/data_analyse/object_detection/runs/train/trashy/weights/best.pt \
    --source /home/mathias/Documents/project_in_ai/data_analyse/data/test1 \
    --name test1_wall \
    --conf-thres 0.8 \
    --save-txt \
    --exist-ok
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.8, device='', exist_ok=True, img_size=640, iou_thres=0.45, name='test1_wall', project='runs/detect', save_conf=False, save_txt=True, source='/home/mathias/Documents/project_in_ai/data_analyse/data/test1', update=False, view_img=False, weights=['/home/mathias/Documents/project_in_ai/data_analyse/object_detection/runs/train/trashy/weights/best.pt'])
# Using torch 1.6.0 CUDA:0 (GeForce GTX 1050 Ti, 4040MB)
#
# Fusing layers...
# Model Summary: 232 layers, 7246518 parameters, 0 gradients
# image 1/4 /home/mathias/Documents/project_in_ai/data_analyse/data/test1/trajectory.png: 480x640 5 trashys, Done. (0.016s)
# video 2/4 (1/628) /home/mathias/Documents/project_in_ai/data_analyse/data/test1/01.mp4: 384x640 1 trashys, Done. (0.015s)
# video 2/4 (2/628) /home/mathias/Documents/project_in_ai/data_analyse/data/test1/01.mp4: 384x640 1 trashys, Done. (0.014s)
# ...

# %% [markdown]
# ## Box left

# %%
# !python yolov5/detect.py \
    --weights /home/mathias/Documents/project_in_ai/data_analyse/object_detection/runs/train/trashy/weights/best.pt \
    --source /home/mathias/Documents/project_in_ai/data_analyse/data/test_box_left \
    --name box_left \
    --conf-thres 0.8 \
    --save-txt \
    --exist-ok
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.8, device='', exist_ok=True, img_size=640, iou_thres=0.45, name='box_left', project='runs/detect', save_conf=False, save_txt=True, source='/home/mathias/Documents/project_in_ai/data_analyse/data/test_box_left', update=False, view_img=False, weights=['/home/mathias/Documents/project_in_ai/data_analyse/object_detection/runs/train/trashy/weights/best.pt'])
# Using torch 1.6.0 CUDA:0 (GeForce GTX 1050 Ti, 4040MB)
#
# Fusing layers...
# Model Summary: 232 layers, 7246518 parameters, 0 gradients
# video 1/3 (1/350) /home/mathias/Documents/project_in_ai/data_analyse/data/test_box_left/box_left_1.mp4: 384x640 1 trashys, Done. (0.017s)
# video 1/3 (2/350) /home/mathias/Documents/project_in_ai/data_analyse/data/test_box_left/box_left_1.mp4: 384x640 1 trashys, Done. (0.016s)
# video 1/3 (3/350) /home/mathias/Documents/project_in_ai/data_analyse/data/test_box_left/box_left_1.mp4: 384x640 1 trashys, Done. (0.018s)
# ...

# %% [markdown]
# ## Box right

# %%
# !python yolov5/detect.py \
    --weights /home/mathias/Documents/project_in_ai/data_analyse/object_detection/runs/train/trashy/weights/best.pt \
    --source /home/mathias/Documents/project_in_ai/data_analyse/data/test_box_right \
    --name box_right \
    --conf-thres 0.8 \
    --save-txt \
    --exist-ok
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.8, device='', exist_ok=True, img_size=640, iou_thres=0.45, name='box_right', project='runs/detect', save_conf=False, save_txt=True, source='/home/mathias/Documents/project_in_ai/data_analyse/data/test_box_right', update=False, view_img=False, weights=['/home/mathias/Documents/project_in_ai/data_analyse/object_detection/runs/train/trashy/weights/best.pt'])
# Using torch 1.6.0 CUDA:0 (GeForce GTX 1050 Ti, 4040MB)
#
# Fusing layers...
# Model Summary: 232 layers, 7246518 parameters, 0 gradients
# video 1/3 (1/331) /home/mathias/Documents/project_in_ai/data_analyse/data/test_box_right/box_right_1.mp4: 384x640 1 trashys, Done. (0.014s)
# video 1/3 (2/331) /home/mathias/Documents/project_in_ai/data_analyse/data/test_box_right/box_right_1.mp4: 384x640 1 trashys, Done. (0.014s)
# video 1/3 (3/331) /home/mathias/Documents/project_in_ai/data_analyse/data/test_box_right/box_right_1.mp4: 384x640 1 trashys, Done. (0.014s)
# ...

# %% [markdown]
# ## Wall left

# %%
# !python yolov5/detect.py \
    --weights /home/mathias/Documents/project_in_ai/data_analyse/object_detection/runs/train/trashy/weights/best.pt \
    --source /home/mathias/Documents/project_in_ai/data_analyse/data/test_wall_left \
    --name wall_left \
    --conf-thres 0.8 \
    --save-txt \
    --exist-ok
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.8, device='', exist_ok=True, img_size=640, iou_thres=0.45, name='wall_left', project='runs/detect', save_conf=False, save_txt=True, source='/home/mathias/Documents/project_in_ai/data_analyse/data/test_wall_left', update=False, view_img=False, weights=['/home/mathias/Documents/project_in_ai/data_analyse/object_detection/runs/train/trashy/weights/best.pt'])
# Using torch 1.6.0 CUDA:0 (GeForce GTX 1050 Ti, 4040MB)
#
# Fusing layers...
# Model Summary: 232 layers, 7246518 parameters, 0 gradients
# video 1/3 (1/334) /home/mathias/Documents/project_in_ai/data_analyse/data/test_wall_left/wall_left_1.mp4: 384x640 1 trashys, Done. (0.019s)
# video 1/3 (2/334) /home/mathias/Documents/project_in_ai/data_analyse/data/test_wall_left/wall_left_1.mp4: 384x640 1 trashys, Done. (0.017s)
# video 1/3 (3/334) /home/mathias/Documents/project_in_ai/data_analyse/data/test_wall_left/wall_left_1.mp4: 384x640 1 trashys, Done. (0.016s)
# ...

# %% [markdown]
# ## Wall right

# %%
# !python yolov5/detect.py \
    --weights /home/mathias/Documents/project_in_ai/data_analyse/object_detection/runs/train/trashy/weights/best.pt \
    --source /home/mathias/Documents/project_in_ai/data_analyse/data/test_wall_right \
    --name wall_right \
    --conf-thres 0.8 \
    --save-txt \
    --exist-ok
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.8, device='', exist_ok=True, img_size=640, iou_thres=0.45, name='wall_right', project='runs/detect', save_conf=False, save_txt=True, source='/home/mathias/Documents/project_in_ai/data_analyse/data/test_wall_right', update=False, view_img=False, weights=['/home/mathias/Documents/project_in_ai/data_analyse/object_detection/runs/train/trashy/weights/best.pt'])
# Using torch 1.6.0 CUDA:0 (GeForce GTX 1050 Ti, 4040MB)
#
# Fusing layers...
# Model Summary: 232 layers, 7246518 parameters, 0 gradients
# video 1/4 (1/337) /home/mathias/Documents/project_in_ai/data_analyse/data/test_wall_right/wall_right_1.mp4: 384x640 1 trashys, Done. (0.015s)
# video 1/4 (2/337) /home/mathias/Documents/project_in_ai/data_analyse/data/test_wall_right/wall_right_1.mp4: 384x640 1 trashys, Done. (0.015s)
# ...

# %% [markdown]
# ## Human left

# %%
# !python yolov5/detect.py \
    --weights /home/mathias/Documents/project_in_ai/data_analyse/object_detection/runs/train/trashy/weights/best.pt \
    --source /home/mathias/Documents/project_in_ai/data_analyse/data/test_human_left \
    --name human_left \
    --conf-thres 0.8 \
    --save-txt \
    --exist-ok
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.8, device='', exist_ok=True, img_size=640, iou_thres=0.45, name='human_left', project='runs/detect', save_conf=False, save_txt=True, source='/home/mathias/Documents/project_in_ai/data_analyse/data/test_human_left', update=False, view_img=False, weights=['/home/mathias/Documents/project_in_ai/data_analyse/object_detection/runs/train/trashy/weights/best.pt'])
# Using torch 1.6.0 CUDA:0 (GeForce GTX 1050 Ti, 4040MB)
#
# Fusing layers...
# Model Summary: 232 layers, 7246518 parameters, 0 gradients
# video 1/3 (1/294) /home/mathias/Documents/project_in_ai/data_analyse/data/test_human_left/left_1.mp4: 384x640 1 trashys, Done. (0.014s)
# video 1/3 (2/294) /home/mathias/Documents/project_in_ai/data_analyse/data/test_human_left/left_1.mp4: 384x640 1 trashys, Done. (0.014s)
# video 1/3 (3/294) /home/mathias/Documents/project_in_ai/data_analyse/data/test_human_left/left_1.mp4: 384x640 1 trashys, Done. (0.016s)
# ...

# %% [markdown]
# ## Human right

# %%
# !python yolov5/detect.py \
    --weights /home/mathias/Documents/project_in_ai/data_analyse/object_detection/runs/train/trashy/weights/best.pt \
    --source /home/mathias/Documents/project_in_ai/data_analyse/data/test_human_right \
    --name human_right \
    --conf-thres 0.8 \
    --save-txt \
    --exist-ok
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.8, device='', exist_ok=True, img_size=640, iou_thres=0.45, name='human_right', project='runs/detect', save_conf=False, save_txt=True, source='/home/mathias/Documents/project_in_ai/data_analyse/data/test_human_right', update=False, view_img=False, weights=['/home/mathias/Documents/project_in_ai/data_analyse/object_detection/runs/train/trashy/weights/best.pt'])
# Using torch 1.6.0 CUDA:0 (GeForce GTX 1050 Ti, 4040MB)
#
# Fusing layers...
# Model Summary: 232 layers, 7246518 parameters, 0 gradients
# video 1/3 (1/278) /home/mathias/Documents/project_in_ai/data_analyse/data/test_human_right/right_1.mp4: 384x640 1 trashys, Done. (0.015s)
# video 1/3 (2/278) /home/mathias/Documents/project_in_ai/data_analyse/data/test_human_right/right_1.mp4: 384x640 1 trashys, Done. (0.015s)
# video 1/3 (3/278) /home/mathias/Documents/project_in_ai/data_analyse/data/test_human_right/right_1.mp4: 384x640 1 trashys, Done. (0.015s)
# ...
